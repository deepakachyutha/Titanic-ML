# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

titanic = pd.read_csv('..\Dataset\TitanicUpdated.csv')

sns.countplot(x='Survived', data=titanic)
plt.title('Count of Survival on Titanic')
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.xticks([0, 1], ['Not Survived', 'Survived'])
plt.show()


sns.heatmap(titanic.corr(), annot=True, fmt = '.2f')
plt.title('Correlation Heatmap of Titanic Dataset')
plt.show()

sns.barplot(x='Sex', y='Survived', data=titanic)
plt.title('Survival Rate Based on Sex')
plt.xlabel("Sex")
plt.ylabel('Survival Rate')
plt.xticks([0,1],['Male','Female'])
plt.show()

sns.histplot(titanic['Age'].dropna(), kde=True, bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\deepa\AppData\Local\Temp\ipykernel_13376\2495142779.py:5: SyntaxWarning: invalid escape sequence '\D'
#   titanic = pd.read_csv('..\Dataset\TitanicUpdated.csv')

# %%
sns.pairplot(titanic)
plt.show()

sns.boxplot(titanic)
plt.show()
