# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

titanic = pd.read_csv('C:\Titanic-ML\Dataset\TitanicUpdated.csv')

sns.countplot(x='Survived', data=titanic)
plt.title('Count of Survival on Titanic')
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.xticks([0, 1], ['Not Survived', 'Survived'])
plt.show()


sns.heatmap(titanic.corr(), annot=True, fmt = '.2f')
plt.title('Correlation Heatmap of Titanic Dataset')
plt.show()

sns.barplot(x='Sex', y='Survived', data=titanic)
plt.title('Survival Rate Based on Sex')
plt.xlabel("Sex")
plt.ylabel('Survival Rate')
plt.xticks([0,1],['Male','Female'])
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\T'
# <>:5: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\deepa\AppData\Local\Temp\ipykernel_17280\3243315971.py:5: SyntaxWarning: invalid escape sequence '\T'
#   titanic = pd.read_csv('C:\Titanic-ML\Dataset\TitanicUpdated.csv')
